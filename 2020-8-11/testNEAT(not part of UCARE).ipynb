# %%
from __future__ import print_function
import os
import numpy as np
import neat
import matplotlib.pyplot as plt

np.random.seed(42)

fitnesses = []
errors = []

def eval_fitnesses(genomes, config):
    global fitnesses
    global errors
    fitnesses.append([])
    errors.append([])
    for genome in genomes:
        genome[1].fitness = 1
        net = neat.nn.FeedForwardNetwork.create(genome[1], config)
        inputs = np.random.random(2)
        res = inputs[0]+inputs[1]
        
        out = net.activate(inputs)
        out*=2
        #print("res: %.4f" % res)
        #print("out[0]: %.4f" % out[0])
        genome[1].fitness -= abs(res - out[0])#**4
        fitnesses[-1].append(genome[1].fitness)
        errors[-1].append(abs((res - out[0])))
        #print("genome[1].fitness: %.4f" % genome[1].fitness)
    
            
def run(config_file, gens):
    # Load configuration.
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)

    # Create the population, which is the top-level object for a NEAT run.
    p = neat.Population(config)

    # Add a stdout reporter to show progress in the terminal.
    #p.add_reporter(neat.StdOutReporter(True))
    #stats = neat.StatisticsReporter()
    #p.add_reporter(stats)
    global fitnesses
    global errors
    fitnesses = []
    errors = []
    winner = p.run(eval_fitnesses, gens)

    print('\nBest genome:\n{!s}'.format(winner))

    winner_net = neat.nn.FeedForwardNetwork.create(winner, config)


if __name__ == '__main__':
    # Determine path to configuration file. This path manipulation is
    # here so that the script will run successfully regardless of the
    # current working directory.
    local_dir = os.getcwd()
    config_path = os.path.join(local_dir, 'config.txt')

# %%
gens = np.arange(1, 200)
best_errors = []
for gen in gens:
    best_error = run(config_path, gen)
    best_errors.append(best_error)

# %%
plt.plot(gens, best_errors)

# %%
gens = np.arange(1, 200)
best_errors = []
for gen in gens:
    best_error = run(config_path, gen)
    best_errors.append(best_error)

# %%
plt.plot(gens, best_errors)
bp = 99 #boundary percentile for axis scaling
#xmin0, xmax0 = np.percentile(gens, 100-bp), np.percentile(gens, bp)
#xmin1, xmax1 = np.percentile(best_errors, 100-bp), np.percentile(best_errors, bp)
#plt.axis([xmin0, xmax0, xmin1, xmax1])

# %%
plt.figure(figsize=(25,10))

run(config_path, 200)

means = []
sds = []
err_means = []

for fitness_i in fitnesses:
    means.append(np.mean(fitness_i))
    sds.append(np.std(fitness_i))
    
for error_i in errors:
    err_means.append(np.mean(error_i))

plt.plot(err_means, 'b')
plt.plot(means, 'g')
plt.plot(sds, 'r')
plt.title("NEAT performance with **2 error-based fitness")
plt.xlabel("Generations", fontsize=14)
plt.ylabel("Value", fontsize=14)
plt.annotate('Mean', xy=(0.85, 0.95), xycoords='axes fraction', color="g")
plt.annotate('Std Dev', xy=(0.85, 0.90), xycoords='axes fraction', color="r")
plt.annotate('Avg Error', xy=(0.85, 0.85), xycoords='axes fraction', color="b")
#errors
# Out:
# Best genome:
# Key: 9116
# Fitness: 0.9998409900748674
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=1.2254599325671747, response=1.0, activation=sigmoid, aggregation=sum)
# 	319 DefaultNodeGene(key=319, bias=0.8017975341916633, response=1.0, activation=sigmoid, aggregation=sum)
# 	613 DefaultNodeGene(key=613, bias=-0.6611182695537199, response=1.0, activation=sigmoid, aggregation=sum)
# 	774 DefaultNodeGene(key=774, bias=-1.0146768576091365, response=1.0, activation=sigmoid, aggregation=sum)
# 	971 DefaultNodeGene(key=971, bias=-2.71381893040367, response=1.0, activation=sigmoid, aggregation=sum)
# 	976 DefaultNodeGene(key=976, bias=1.828315204447028, response=1.0, activation=sigmoid, aggregation=sum)
# 	1088 DefaultNodeGene(key=1088, bias=1.6691030737192607, response=1.0, activation=sigmoid, aggregation=sum)
# 	1268 DefaultNodeGene(key=1268, bias=1.2326937205605748, response=1.0, activation=sigmoid, aggregation=sum)
# 	1303 DefaultNodeGene(key=1303, bias=-0.20754269661125482, response=1.0, activation=sigmoid, aggregation=sum)
# 	1345 DefaultNodeGene(key=1345, bias=4.666881839756665, response=1.0, activation=sigmoid, aggregation=sum)
# 	1371 DefaultNodeGene(key=1371, bias=1.6817790865697348, response=1.0, activation=sigmoid, aggregation=sum)
# 	1449 DefaultNodeGene(key=1449, bias=-1.788982702079834, response=1.0, activation=sigmoid, aggregation=sum)
# 	1481 DefaultNodeGene(key=1481, bias=0.2509020283413159, response=1.0, activation=sigmoid, aggregation=sum)
# 	1515 DefaultNodeGene(key=1515, bias=-1.4640416035365837, response=1.0, activation=sigmoid, aggregation=sum)
# 	1611 DefaultNodeGene(key=1611, bias=0.08268550508040085, response=1.0, activation=sigmoid, aggregation=sum)
# 	1641 DefaultNodeGene(key=1641, bias=0.5470819369320088, response=1.0, activation=sigmoid, aggregation=sum)
# 	1645 DefaultNodeGene(key=1645, bias=1.0877361673215253, response=1.0, activation=sigmoid, aggregation=sum)
# 	1657 DefaultNodeGene(key=1657, bias=-0.14765860472101766, response=1.0, activation=sigmoid, aggregation=sum)
# 	1668 DefaultNodeGene(key=1668, bias=-0.0033036093908010156, response=1.0, activation=sigmoid, aggregation=sum)
# 	1705 DefaultNodeGene(key=1705, bias=0.0802560896863282, response=1.0, activation=sigmoid, aggregation=sum)
# 	1713 DefaultNodeGene(key=1713, bias=-1.151100290111272, response=1.0, activation=sigmoid, aggregation=sum)
# 	1725 DefaultNodeGene(key=1725, bias=-0.7122040906465015, response=1.0, activation=sigmoid, aggregation=sum)
# 	1748 DefaultNodeGene(key=1748, bias=-0.0817743931198977, response=1.0, activation=sigmoid, aggregation=sum)
# 	1766 DefaultNodeGene(key=1766, bias=0.8330426998253819, response=1.0, activation=sigmoid, aggregation=sum)
# 	1798 DefaultNodeGene(key=1798, bias=0.21501148202184858, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-2, 0), weight=0.4436314610153317, enabled=True)
# 	DefaultConnectionGene(key=(-2, 1481), weight=-1.2255219526425511, enabled=True)
# 	DefaultConnectionGene(key=(-2, 1611), weight=-0.6540998382678072, enabled=True)
# 	DefaultConnectionGene(key=(-2, 1748), weight=2.9494883207958114, enabled=True)
# 	DefaultConnectionGene(key=(-1, 774), weight=-1.7018740178143208, enabled=True)
# 	DefaultConnectionGene(key=(0, 971), weight=-2.8648853991410843, enabled=True)
# 	DefaultConnectionGene(key=(0, 1303), weight=0.29283401823784116, enabled=True)
# 	DefaultConnectionGene(key=(774, 319), weight=0.8369760601818365, enabled=False)
# 	DefaultConnectionGene(key=(774, 976), weight=1.3755620303458986, enabled=True)
# 	DefaultConnectionGene(key=(774, 1766), weight=1.5941266800042644, enabled=True)
# 	DefaultConnectionGene(key=(976, 1088), weight=-1.4928526101267345, enabled=False)
# 	DefaultConnectionGene(key=(976, 1713), weight=1.412312156794439, enabled=True)
# 	DefaultConnectionGene(key=(1088, 1449), weight=-1.3980888727699008, enabled=True)
# 	DefaultConnectionGene(key=(1268, 1371), weight=-1.7292324071683727, enabled=True)
# 	DefaultConnectionGene(key=(1303, 774), weight=0.4674499559393791, enabled=True)
# 	DefaultConnectionGene(key=(1345, 613), weight=5.298399639840409, enabled=True)
# 	DefaultConnectionGene(key=(1345, 1705), weight=-0.2706858035854447, enabled=True)
# 	DefaultConnectionGene(key=(1371, 613), weight=-0.4589683574769648, enabled=False)
# 	DefaultConnectionGene(key=(1449, 1725), weight=1.889730159078524, enabled=True)
# 	DefaultConnectionGene(key=(1515, 319), weight=-0.8814018898754423, enabled=True)
# 	DefaultConnectionGene(key=(1611, 1657), weight=-0.5143832693158102, enabled=True)
# 	DefaultConnectionGene(key=(1641, 971), weight=-1.5296984731664114, enabled=False)
# 	DefaultConnectionGene(key=(1641, 1303), weight=-1.5182971644242518, enabled=True)
# 	DefaultConnectionGene(key=(1641, 1668), weight=0.18100212608767435, enabled=True)
# 	DefaultConnectionGene(key=(1645, 774), weight=-0.8649222440651876, enabled=True)
# 	DefaultConnectionGene(key=(1668, 971), weight=-2.088838434845291, enabled=True)
# 	DefaultConnectionGene(key=(1668, 976), weight=0.289034188744975, enabled=True)
# 	DefaultConnectionGene(key=(1705, 319), weight=-0.6143514979479958, enabled=True)
# 	DefaultConnectionGene(key=(1705, 613), weight=-1.9915780825093958, enabled=False)
# 	DefaultConnectionGene(key=(1705, 1515), weight=2.65688224983879, enabled=True)
# 	DefaultConnectionGene(key=(1705, 1798), weight=0.644234685496528, enabled=True)
# 	DefaultConnectionGene(key=(1713, 1088), weight=0.2124113981621199, enabled=True)
# 	DefaultConnectionGene(key=(1725, 1268), weight=-0.990376590324208, enabled=True)
# 	DefaultConnectionGene(key=(1766, 1268), weight=-0.4622901975520096, enabled=True)
# 	DefaultConnectionGene(key=(1798, 613), weight=-1.2167394448719637, enabled=True)
# Text(0.85, 0.85, 'Avg Error')

# %%
print("Using fitness based on error**2")
# Out:
# Using fitness based on error**2

# %%
plt.figure(figsize=(25,10))

run(config_path, 200)

means = []
sds = []
err_means = []

for fitness_i in fitnesses:
    means.append(np.mean(fitness_i))
    sds.append(np.std(fitness_i))
    
for error_i in errors:
    err_means.append(np.mean(error_i))

plt.plot(err_means, 'b')
plt.plot(means, 'g')
plt.plot(sds, 'r')
plt.title("NEAT performance with **4 error-based fitness")
plt.xlabel("Generations", fontsize=14)
plt.ylabel("Value", fontsize=14)
plt.annotate('Mean', xy=(0.85, 0.95), xycoords='axes fraction', color="g")
plt.annotate('Std Dev', xy=(0.85, 0.90), xycoords='axes fraction', color="r")
plt.annotate('Avg Error', xy=(0.85, 0.85), xycoords='axes fraction', color="b")
#errors
# Out:
# Best genome:
# Key: 9003
# Fitness: 0.9999999997497507
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=0.8614876950625246, response=1.0, activation=sigmoid, aggregation=sum)
# 	531 DefaultNodeGene(key=531, bias=-0.11294323997359693, response=1.0, activation=sigmoid, aggregation=sum)
# 	710 DefaultNodeGene(key=710, bias=1.5176272597945464, response=1.0, activation=sigmoid, aggregation=sum)
# 	790 DefaultNodeGene(key=790, bias=-0.7486123036738721, response=1.0, activation=sigmoid, aggregation=sum)
# 	1025 DefaultNodeGene(key=1025, bias=1.5285750732309782, response=1.0, activation=sigmoid, aggregation=sum)
# 	1195 DefaultNodeGene(key=1195, bias=-0.3405909136917389, response=1.0, activation=sigmoid, aggregation=sum)
# 	1293 DefaultNodeGene(key=1293, bias=0.2118662716257633, response=1.0, activation=sigmoid, aggregation=sum)
# 	1426 DefaultNodeGene(key=1426, bias=0.42123759848550524, response=1.0, activation=sigmoid, aggregation=sum)
# 	1587 DefaultNodeGene(key=1587, bias=0.15562313840061692, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-2, 0), weight=-1.1879431025316145, enabled=True)
# 	DefaultConnectionGene(key=(-2, 710), weight=0.25017872745120723, enabled=False)
# 	DefaultConnectionGene(key=(-2, 1587), weight=0.005590063460031214, enabled=True)
# 	DefaultConnectionGene(key=(1426, 1587), weight=-0.5963701076509311, enabled=True)
# 	DefaultConnectionGene(key=(1587, 531), weight=-0.48780017304364864, enabled=True)
# Text(0.85, 0.85, 'Avg Error')

# %%
print("Using **4 error, whereas before I was using **2 error")
# Out:
# Using **4 error, whereas before I was using **2 error

# %%
plt.figure(figsize=(25,10))

run(config_path, 200)

means = []
sds = []
err_means = []

for fitness_i in fitnesses:
    means.append(np.mean(fitness_i))
    sds.append(np.std(fitness_i))
    
for error_i in errors:
    err_means.append(np.mean(error_i))

plt.plot(err_means, 'b')
plt.plot(means, 'g')
plt.plot(sds, 'r')
plt.title("NEAT performance with raw error-based fitness")
plt.xlabel("Generations", fontsize=14)
plt.ylabel("Value", fontsize=14)
plt.annotate('Mean', xy=(0.85, 0.95), xycoords='axes fraction', color="g")
plt.annotate('Std Dev', xy=(0.85, 0.90), xycoords='axes fraction', color="r")
plt.annotate('Avg Error', xy=(0.85, 0.85), xycoords='axes fraction', color="b")
#errors
# Out:
# Best genome:
# Key: 9131
# Fitness: 0.9766429132214381
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=2.5747903253975686, response=1.0, activation=sigmoid, aggregation=sum)
# 	788 DefaultNodeGene(key=788, bias=1.5542225019854634, response=1.0, activation=sigmoid, aggregation=sum)
# 	979 DefaultNodeGene(key=979, bias=-1.3263249663038046, response=1.0, activation=sigmoid, aggregation=sum)
# 	1342 DefaultNodeGene(key=1342, bias=-0.8598869054731565, response=1.0, activation=sigmoid, aggregation=sum)
# 	1444 DefaultNodeGene(key=1444, bias=0.2753476924071053, response=1.0, activation=sigmoid, aggregation=sum)
# 	1514 DefaultNodeGene(key=1514, bias=0.20507956890349263, response=1.0, activation=sigmoid, aggregation=sum)
# 	1804 DefaultNodeGene(key=1804, bias=0.2796623228029974, response=1.0, activation=sigmoid, aggregation=sum)
# 	1812 DefaultNodeGene(key=1812, bias=-0.1677910678297043, response=1.0, activation=sigmoid, aggregation=sum)
# 	1862 DefaultNodeGene(key=1862, bias=-1.804298923905939, response=1.0, activation=sigmoid, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-2, 788), weight=0.5450972923854803, enabled=True)
# 	DefaultConnectionGene(key=(-1, 1804), weight=-0.32687297451226155, enabled=False)
# 	DefaultConnectionGene(key=(0, 1342), weight=-0.6367062041834961, enabled=True)
# 	DefaultConnectionGene(key=(788, 1514), weight=-0.3032414468264346, enabled=True)
# 	DefaultConnectionGene(key=(788, 1812), weight=0.04931456727118777, enabled=True)
# 	DefaultConnectionGene(key=(1514, 0), weight=0.8874637149642366, enabled=True)
# 	DefaultConnectionGene(key=(1514, 979), weight=0.3749257121410005, enabled=True)
# 	DefaultConnectionGene(key=(1514, 1862), weight=-1.2393345254330856, enabled=True)
# 	DefaultConnectionGene(key=(1812, 1444), weight=2.6216148776237906, enabled=True)
# 	DefaultConnectionGene(key=(1812, 1514), weight=-0.9047319802076397, enabled=True)
# 	DefaultConnectionGene(key=(1862, 0), weight=2.428770040442527, enabled=True)
# Text(0.85, 0.85, 'Avg Error')

# %%
print("Using raw error")
# Out:
# Using raw error
